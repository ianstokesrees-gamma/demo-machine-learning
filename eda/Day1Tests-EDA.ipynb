# %%
import pandas as pd

# %%
df = pd.read_csv('../data/australian_open.csv')

# %%
df
# Out:
#       rally  serve hitpoint      speed  net.clearance  distance.from.sideline  \
# 0         4      1        B  35.515042      -0.021725                3.474766
# 1         4      2        B  33.382640       1.114202                2.540801
# 2        23      1        B  22.316690      -0.254046                3.533166
# 3         9      1        F  36.837309       0.766694                0.586885
# 4         4      1        B  35.544208       0.116162                0.918725
# ...     ...    ...      ...        ...            ...                     ...
# 4995     11      1        F  35.521499       2.812817                0.953089
# 4996      6      2        F  21.889213      -0.058416                1.493543
# 4997      8      1        F  16.386081      -0.033785                3.936636
# 4998      4      2        F  41.853105       0.391268                0.811879
# 4999      5      1        B  29.960013      -0.369827                0.515396
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   rally                               5000 non-null   int64
#  1   serve                               5000 non-null   int64
#  2   hitpoint                            5000 non-null   object
#  3   speed                               5000 non-null   float64
#  4   net.clearance                       5000 non-null   float64
#  5   distance.from.sideline              5000 non-null   float64
#  6   depth                               5000 non-null   float64
#  7   outside.sideline                    5000 non-null   bool
#  8   outside.baseline                    5000 non-null   bool
#  9   player.distance.travelled           5000 non-null   float64
#  10  player.impact.depth                 5000 non-null   float64
# ...

# %%
df.describe()
# Out:
#              rally        serve        speed  net.clearance  \
# count  5000.000000  5000.000000  5000.000000    5000.000000
# mean      6.073800     1.419200    31.161443       0.630771
# std       3.729388     0.493478     8.160724       1.032237
# min       3.000000     1.000000     5.340688      -0.998184
# 25%       3.000000     1.000000    25.902134      -0.033606
# 50%       5.000000     1.000000    32.913270       0.428872
# 75%       7.000000     2.000000    37.050218       0.957190
# max      38.000000     2.000000    60.414369      12.815893
#
#        distance.from.sideline        depth  player.distance.travelled  \
# count             5000.000000  5000.000000                5000.000000
# mean                 1.446501     4.582527                   2.940785
# std                  1.107850     3.194891                   1.821582
# min                  0.000378     0.000282                   0.000000
# 25%                  0.535640     1.738331                   1.632093
# ...

# %%
simdf = pd.DataFrame({c : pd.Series(dtype=dt) for c,dt in zip(df.columns, df.dtypes)})

# %%
simdf
# Out:
# Empty DataFrame
# Columns: [rally, serve, hitpoint, speed, net.clearance, distance.from.sideline, depth, outside.sideline, outside.baseline, player.distance.travelled, player.impact.depth, player.impact.distance.from.center, player.depth, player.distance.from.center, previous.speed, previous.net.clearance, previous.distance.from.sideline, previous.depth, opponent.depth, opponent.distance.from.center, same.side, previous.hitpoint, previous.time.to.net, server.is.impact.player, id, outcome]
# Index: []
#
# [0 rows x 26 columns]

# %%
simdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   rally                               0 non-null      int64
#  1   serve                               0 non-null      int64
#  2   hitpoint                            0 non-null      object
#  3   speed                               0 non-null      float64
#  4   net.clearance                       0 non-null      float64
#  5   distance.from.sideline              0 non-null      float64
#  6   depth                               0 non-null      float64
#  7   outside.sideline                    0 non-null      bool
#  8   outside.baseline                    0 non-null      bool
#  9   player.distance.travelled           0 non-null      float64
#  10  player.impact.depth                 0 non-null      float64
# ...

# %%
df.hitpoint.value_counts()
# Out:
# F    2738
# B    1815
# U     349
# V      98
# Name: hitpoint, dtype: int64

# %%
df.dtypes['rally']
# Out:
# dtype('int64')

# %%
df.rally.dtype
# Out:
# dtype('int64')

# %%
type(df.rally[7])
# Out:
# numpy.int64

# %%
import numpy as np
np.int64
# Out:
# numpy.int64

# %%
np.bool8
# Out:
# numpy.bool_

# %%
type(df.hitpoint[7])
# Out:
# str

# %%
df.hitpoint.dtype
# Out:
# dtype('O')

# %%
df['same.side'].value_counts()
# Out:
# False    3672
# True     1328
# Name: same.side, dtype: int64

# %%
df['same.side'].value_counts()[False]
# Out:
# 3672

# %%
df.rally.std()
# Out:
# 3.7293880499413588

# %%
df.hitpoint.value_counts().keys()
# Out:
# Index(['F', 'B', 'U', 'V'], dtype='object')

# %%
sum(df.hitpoint.value_counts())
# Out:
# 5000

# %%
for k in df.hitpoint.value_counts().keys():
    print(k)
# Out:
# F
# B
# U
# V

# %%
import sys

# %%
sys.path
# Out:
# ['/Users/stokesreesian/training/demo-machine-learning/eda',
#  '/Users/stokesreesian/training/demo-machine-learning/src',
#  '/opt/anaconda3/envs/testing/lib/python310.zip',
#  '/opt/anaconda3/envs/testing/lib/python3.10',
#  '/opt/anaconda3/envs/testing/lib/python3.10/lib-dynload',
#  '',
#  '/opt/anaconda3/envs/testing/lib/python3.10/site-packages',
#  '/opt/anaconda3/envs/testing/lib/python3.10/site-packages/IPython/extensions',
#  '/Users/stokesreesian/.ipython']

# %%
del sys.modules['dfsimulator']

# %%
import dfsimulator

# %%
sim = dfsimulator.DataFrameSimulator(df)

# %%
sim.characterize()
# Out:
# rally		int64
# serve		int64
# hitpoint		object
# speed		float64
# net.clearance		float64
# distance.from.sideline		float64
# depth		float64
# outside.sideline		bool
# outside.baseline		bool
# player.distance.travelled		float64
# player.impact.depth		float64
# player.impact.distance.from.center		float64
# player.depth		float64
# player.distance.from.center		float64
# previous.speed		float64
# previous.net.clearance		float64
# previous.distance.from.sideline		float64
# previous.depth		float64
# opponent.depth		float64
# opponent.distance.from.center		float64
# same.side		bool
# previous.hitpoint		object
# previous.time.to.net		float64
# server.is.impact.player		bool
# id		int64
# outcome		object

# %%
sim.simulate(10)
# Out:
#    rally  serve hitpoint      speed  net.clearance  distance.from.sideline  \
# 0      9      2        B  29.863666       1.132692                1.863958
# 1      1      2        F  25.781045       2.230719                2.815383
# 2     10      2        U  27.043800       1.651831                1.410877
# 3      9      3        F  36.378415       2.654995                2.553190
# 4     11      2        B  18.485724       1.644836                0.839061
# 5      9      3        F  42.434643      -0.079778                1.231469
# 6      7      2        F  45.238840      -0.877507                2.875946
# 7     11      3        U  30.850116       0.277279                2.456034
# 8      5      2        B  19.825804       1.209588                0.823302
# 9      9      1        F  13.612559       0.709135                1.770764
#
#       depth  outside.sideline  outside.baseline  player.distance.travelled  \
# ...

# %%
df.head()
# Out:
#    rally  serve hitpoint      speed  net.clearance  distance.from.sideline  \
# 0      4      1        B  35.515042      -0.021725                3.474766
# 1      4      2        B  33.382640       1.114202                2.540801
# 2     23      1        B  22.316690      -0.254046                3.533166
# 3      9      1        F  36.837309       0.766694                0.586885
# 4      4      1        B  35.544208       0.116162                0.918725
#
#       depth  outside.sideline  outside.baseline  player.distance.travelled  \
# 0  6.797621             False             False                   1.467570
# 1  2.608708             False              True                   2.311931
# 2  9.435749             False             False                   3.903728
# 3  3.342180              True             False                   0.583745
# 4  5.499119             False             False                   2.333456
#
# ...

# %%
simdf = sim.simulate(5000)

# %%
simdf.describe()
# Out:
#              rally        serve        speed  net.clearance  \
# count  5000.000000  5000.000000  5000.000000    5000.000000
# mean      6.601200     1.924800    30.982266       0.622852
# std       3.743229     0.556423     8.078190       1.033580
# min      -7.000000     0.000000     3.724267      -2.948046
# 25%       4.000000     2.000000    25.529618      -0.052462
# 50%       7.000000     2.000000    31.040294       0.614065
# 75%       9.000000     2.000000    36.160446       1.313598
# max      19.000000     4.000000    66.684235       4.337744
#
#        distance.from.sideline        depth  player.distance.travelled  \
# count             5000.000000  5000.000000                5000.000000
# mean                 1.434462     4.654054                   2.952258
# std                  1.111700     3.224756                   1.849830
# min                 -2.037468    -6.535315                  -4.040526
# 25%                  0.680059     2.515105                   1.702820
# ...

# %%
df.describe()
# Out:
#              rally        serve        speed  net.clearance  \
# count  5000.000000  5000.000000  5000.000000    5000.000000
# mean      6.073800     1.419200    31.161443       0.630771
# std       3.729388     0.493478     8.160724       1.032237
# min       3.000000     1.000000     5.340688      -0.998184
# 25%       3.000000     1.000000    25.902134      -0.033606
# 50%       5.000000     1.000000    32.913270       0.428872
# 75%       7.000000     2.000000    37.050218       0.957190
# max      38.000000     2.000000    60.414369      12.815893
#
#        distance.from.sideline        depth  player.distance.travelled  \
# count             5000.000000  5000.000000                5000.000000
# mean                 1.446501     4.582527                   2.940785
# std                  1.107850     3.194891                   1.821582
# min                  0.000378     0.000282                   0.000000
# 25%                  0.535640     1.738331                   1.632093
# ...

# %%
import inspect
inspect.isclass(bool)
# Out:
# True

# %%
base_series = df.hitpoint

# %%
base_series
# Out:
# 0       B
# 1       B
# 2       B
# 3       F
# 4       B
#        ..
# 4995    F
# 4996    F
# 4997    F
# 4998    F
# 4999    B
# Name: hitpoint, Length: 5000, dtype: object

# %%
counts = base_series.value_counts()

# %%
counts
# Out:
# F    2738
# B    1815
# U     349
# V      98
# Name: hitpoint, dtype: int64

# %%
total = sum(counts)

# %%
total
# Out:
# 5000

# %%
2738+1815+349+98
# Out:
# 5000

# %%
freq_dict = {entry: counts[entry]/total for entry in counts.keys()}

# %%
for entry in counts:
    print(entry)
# Out:
# 2738
# 1815
# 349
# 98

# %%
freq_dict
# Out:
# {'F': 0.5476, 'B': 0.363, 'U': 0.0698, 'V': 0.0196}

# %%
np.ndarray(sim._column_models['hitpoint'].freq_dict.keys())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nf/_rm9_cdj2_d11br5rm7l9z7c0000gn/T/ipykernel_40957/370550028.py in <module>
# ----> 1 np.ndarray(sim._column_models['hitpoint'].freq_dict.keys())
#
# TypeError: 'dict_keys' object does not support indexing

# %%
list(sim._column_models['hitpoint'].freq_dict.values())
# Out:
# [0.5476, 0.363, 0.0698, 0.0196]

# %%
simdf
# Out:
#       rally  serve hitpoint      speed  net.clearance  distance.from.sideline  \
# 0        10      2        B  32.250456       3.027813                2.178211
# 1         1      1        F  25.085910      -2.058146                2.822896
# 2         6      1        B  28.779220       0.300126                2.568095
# 3         1      2        B  18.718010       2.968404                0.097512
# 4        12      2        F  45.496904       0.002741                1.515374
# ...     ...    ...      ...        ...            ...                     ...
# 4995      8      2        F  26.619048       0.073252                1.994386
# 4996      8      3        F  17.288414      -0.413501                1.256709
# 4997     -1      3        B  31.660205      -0.146895                2.530503
# 4998      2      1        B  30.797883       0.379582                0.924169
# 4999      9      2        F  26.341028       0.471415                1.503531
#
# ...

# %%
import json

result = simdf.to_json(orient='records')
parsed = json.loads(result)
with open('../data/simulated.json', 'w') as fh:
    fh.write(json.dumps(parsed, indent=4))

# %%
pwd
# Out:
# '/Users/stokesreesian/training/demo-machine-learning/eda'
